# %%
print("Hello world!")
# Out:
# Hello world!

# %% [raw]
# VARIABLES

# %%
failed_subjects = "6"
name="John"
print('Dear Mrs Badger')
print('Your son '+name+' is failing '+failed_subjects+ ' subjects.')
print(name+' will need to redo '+failed_subjects+ ' courses.')
name='Eric'
print(name+' is doing well in geography.')
# Out:
# Dear Mrs Badger
# Your son John is failing 6 subjects.
# John will need to redo 6 courses.
# Eric is doing well in geography.

# %% [markdown]
# DATATYPES AND TYPECASTING

# %%
failed_subjects = 2
name="John"
print('Dear Mrs Badger')
print('Your son '+name+' is failing '+str(failed_subjects)+ ' subjects.')
#failed_subject is intmtype ,we cannot make it print until it is string..so we 
#explicitly converting it into str in the above statement
print(name+' will need to redo '+str(failed_subjects)+ ' courses.')
name='Eric'
print(name+' is doing well in geography.')
#Boolean True or False
#isGoingToParty(camelcase) or is_going_to_party = True
#a='it's' -->a="it's" or 'it\'s' -->backslash-->escaping characters

#type() function
print(type('hello'))
print(type(1))
print(type(1.73))
print(type(True))
# Out:
# Dear Mrs Badger
# Your son John is failing 2 subjects.
# John will need to redo 2 courses.
# Eric is doing well in geography.
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = int(1)        # a will be 1
b = int(2.5)      # b will be 2
c = int("3")      # c will be 3
c1 = int(float("3.4"))   # c1 will be...
#we cannot convert the above int("3.4") which is a string but in float form
#to convert,,first change into float and then to int
d = float(1)      # d will be 1.0
e = float(2.5)    # e will be 2.5
f = float("3")    # f will be 3.0
g = float("4.23") # g will be 4.23
h = str("80s")    # h will be '80s'
i = str(22)       # i will be '22'
j = str(3.01)     # j will be '3.01'

print([a,b,c,d,e,f,g,h,i,j])
print(j+" done")
# Out:
# [1, 2, 3, 1.0, 2.5, 3.0, 4.23, '80s', '22', '3.01']
# 3.01 done

# %%
item = 'fruit'
price = 10.34
stock = 100
is_in_stock = True
print(item,price,stock)
# Out:
# fruit 10.34 100

# %% [markdown]
# ARCADE DAY PASS CHALLENGE
#
# # 🕹️ Arcade Day Pass Tracker — Challenge Steps
# #
# # 1) Create variables to store:
# #    - customer name
# #    - number of passes
# #    - tokens per pass
# #    - price per pass
# #    - tokens required per game
# #
# # 2) Calculate:
# #    - total tokens
# #    - total cost
# #    - games available  (use 'floor division' to get a whole number)
# #
# # 3) Print a summary with:
# #    - customer name
# #    - passes bought
# #    - total tokens
# #    - total cost
# #    - games available

# %%
#Variables
customer_name="Jass"
passes_bought=5
tokens_per_pass=30
pass_price=12.50
tokens_per_game=4

#Calculations
total_tokens=passes_bought * tokens_per_pass
total_cost=passes_bought * pass_price
games_available=total_tokens // tokens_per_game #floor division

#Receipt
print("====ARCADE DAY PASS====")
print("Customer:",customer_name)
print("Passes:",passes_bought)
print("Tokens:",total_tokens)
print("Total Cost: $"+str(total_cost))
#to print total cost as 62.50
print(f"Total Cost: ${total_cost:.2f}")
print("Games Available:"+ str(games_available))
# Out:
# ====ARCADE DAY PASS====
# Customer: Jass
# Passes: 5
# Tokens: 150
# Total Cost: $62.5
# Total Cost: $62.50
# Games Available:37

# %% [markdown]
# USER INPUT

# %%
name = input('what is your name?:')
age = input('What is your age?')
print('Wassup '+ name + '.Your are '+ age+ ' years old!')
# Out:
# what is your name?: Jass
# What is your age? 23
# Wassup Jass.Your are 23 years old!

# %%
num1=input('Enter a number:')
num2=input('Enter a second number:')
#since user input is taken as string ,it doesn't evaluate
#so we typecast it
answer = float(num1) + float(num2)
print(answer)
# Out:
# Enter a number: 7
# Enter a second number: 14
# 21.0

# %%
firstname=input("Enter your name:")
dist_in_km=input("Enter the distance(in km):")
#km_to_miles=str(float(dist_in_km)/1.609)
km_to_miles=float(dist_in_km)/1.609
print(f'Hello {firstname.title()}! {dist_in_km}km is equivalent to {round(km_to_miles,1)}miles.')

#title() and round()

#print("Hello "+firstname.title())#to capitalize first letter
#print(dist_in_km +" km")
#print(km_to_miles +" miles")
# Out:
# Enter your name: jasss
# Enter the distance(in km): 12
# Hello Jasss! 12km is equivalent to 7.5miles.
